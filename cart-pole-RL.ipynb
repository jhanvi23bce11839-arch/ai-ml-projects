# %%
import gymnasium as gym
from stable_baselines3 import PPO

# %%
env = gym.make("CartPole-v1")

# %%
model = PPO(
    "MlpPolicy",
    env,
    verbose=1
)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model = PPO(
    "MlpPolicy",
    env,
    verbose=1
)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=100000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23.1     |
# |    ep_rew_mean     | 23.1     |
# | time/              |          |
# |    fps             | 1102     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26.6        |
# |    ep_rew_mean          | 26.6        |
# | time/                   |             |
# |    fps                  | 912         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009587433 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.685      |
# |    explained_variance   | -0.00398    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.02        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0212     |
# |    value_loss           | 58.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 32.2        |
# |    ep_rew_mean          | 32.2        |
# | time/                   |             |
# |    fps                  | 825         |
# |    iterations           | 3           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009177668 |
# |    clip_fraction        | 0.0778      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.664      |
# |    explained_variance   | 0.0641      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12          |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0213     |
# |    value_loss           | 37.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 46.9        |
# |    ep_rew_mean          | 46.9        |
# | time/                   |             |
# |    fps                  | 752         |
# |    iterations           | 4           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.011376227 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.631      |
# |    explained_variance   | 0.284       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.1        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.024      |
# |    value_loss           | 49.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60.7        |
# |    ep_rew_mean          | 60.7        |
# | time/                   |             |
# |    fps                  | 727         |
# |    iterations           | 5           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009317057 |
# |    clip_fraction        | 0.0668      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.611      |
# |    explained_variance   | 0.223       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.4        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0136     |
# |    value_loss           | 63.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 77          |
# |    ep_rew_mean          | 77          |
# | time/                   |             |
# |    fps                  | 681         |
# |    iterations           | 6           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008828285 |
# |    clip_fraction        | 0.0784      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.583      |
# |    explained_variance   | 0.389       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.1        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0153     |
# |    value_loss           | 65.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 93.9         |
# |    ep_rew_mean          | 93.9         |
# | time/                   |              |
# |    fps                  | 595          |
# |    iterations           | 7            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0059618633 |
# |    clip_fraction        | 0.0457       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.567       |
# |    explained_variance   | 0.546        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.4          |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00749     |
# |    value_loss           | 56.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 111         |
# |    ep_rew_mean          | 111         |
# | time/                   |             |
# |    fps                  | 558         |
# |    iterations           | 8           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.004855773 |
# |    clip_fraction        | 0.0508      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.582      |
# |    explained_variance   | 0.803       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.39        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00599    |
# |    value_loss           | 33.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 130         |
# |    ep_rew_mean          | 130         |
# | time/                   |             |
# |    fps                  | 497         |
# |    iterations           | 9           |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.003131128 |
# |    clip_fraction        | 0.0284      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.571      |
# |    explained_variance   | 0.844       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.3        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00452    |
# |    value_loss           | 26.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 148         |
# |    ep_rew_mean          | 148         |
# | time/                   |             |
# |    fps                  | 478         |
# |    iterations           | 10          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.001632163 |
# |    clip_fraction        | 0.0246      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.571      |
# |    explained_variance   | 0.93        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.17        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00303    |
# |    value_loss           | 17.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 168          |
# |    ep_rew_mean          | 168          |
# | time/                   |              |
# |    fps                  | 474          |
# |    iterations           | 11           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0039032141 |
# |    clip_fraction        | 0.0472       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.569       |
# |    explained_variance   | 0.884        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.83         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.0103      |
# |    value_loss           | 17.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 184         |
# |    ep_rew_mean          | 184         |
# | time/                   |             |
# |    fps                  | 469         |
# |    iterations           | 12          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.005254958 |
# |    clip_fraction        | 0.039       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.572      |
# |    explained_variance   | 0.908       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.739       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0082     |
# |    value_loss           | 10.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 202          |
# |    ep_rew_mean          | 202          |
# | time/                   |              |
# |    fps                  | 459          |
# |    iterations           | 13           |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0018576037 |
# |    clip_fraction        | 0.0146       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.563       |
# |    explained_variance   | 0.0112       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.87         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00197     |
# |    value_loss           | 23.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 218         |
# |    ep_rew_mean          | 218         |
# | time/                   |             |
# |    fps                  | 458         |
# |    iterations           | 14          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.004228229 |
# |    clip_fraction        | 0.0374      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.552      |
# |    explained_variance   | 0.413       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.208       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00127    |
# |    value_loss           | 2.59        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 239          |
# |    ep_rew_mean          | 239          |
# | time/                   |              |
# |    fps                  | 453          |
# |    iterations           | 15           |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0055318875 |
# |    clip_fraction        | 0.0545       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.556       |
# |    explained_variance   | 0.826        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.226        |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.0123      |
# |    value_loss           | 1.63         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | 256          |
# | time/                   |              |
# |    fps                  | 442          |
# |    iterations           | 16           |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0058281776 |
# |    clip_fraction        | 0.0673       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.554       |
# |    explained_variance   | 0.634        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0881       |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00885     |
# |    value_loss           | 1.01         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 271          |
# |    ep_rew_mean          | 271          |
# | time/                   |              |
# |    fps                  | 434          |
# |    iterations           | 17           |
# |    time_elapsed         | 80           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0056914277 |
# |    clip_fraction        | 0.0453       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.551       |
# |    explained_variance   | 0.292        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000434    |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00366     |
# |    value_loss           | 0.538        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 288         |
# |    ep_rew_mean          | 288         |
# | time/                   |             |
# |    fps                  | 425         |
# |    iterations           | 18          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.002850601 |
# |    clip_fraction        | 0.0165      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.563      |
# |    explained_variance   | 0.0284      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.054       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.000327   |
# |    value_loss           | 0.343       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 305          |
# |    ep_rew_mean          | 305          |
# | time/                   |              |
# |    fps                  | 424          |
# |    iterations           | 19           |
# |    time_elapsed         | 91           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0053440062 |
# |    clip_fraction        | 0.0305       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.545       |
# |    explained_variance   | -0.0351      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00629     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.000998    |
# |    value_loss           | 0.215        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 323         |
# |    ep_rew_mean          | 323         |
# | time/                   |             |
# |    fps                  | 421         |
# |    iterations           | 20          |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.005584514 |
# |    clip_fraction        | 0.0263      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.546      |
# |    explained_variance   | 0.00608     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00697     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.000966   |
# |    value_loss           | 0.133       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 338         |
# |    ep_rew_mean          | 338         |
# | time/                   |             |
# |    fps                  | 413         |
# |    iterations           | 21          |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.005272094 |
# |    clip_fraction        | 0.0551      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.529      |
# |    explained_variance   | -0.0245     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0164      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00403    |
# |    value_loss           | 0.0821      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 353         |
# |    ep_rew_mean          | 353         |
# | time/                   |             |
# |    fps                  | 410         |
# |    iterations           | 22          |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.006937137 |
# |    clip_fraction        | 0.0721      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.542      |
# |    explained_variance   | 0.0393      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00124     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00309    |
# |    value_loss           | 0.052       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 369          |
# |    ep_rew_mean          | 369          |
# | time/                   |              |
# |    fps                  | 406          |
# |    iterations           | 23           |
# |    time_elapsed         | 115          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0067355866 |
# |    clip_fraction        | 0.0366       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.547       |
# |    explained_variance   | -0.00595     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00365      |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00128     |
# |    value_loss           | 0.0342       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 386          |
# |    ep_rew_mean          | 386          |
# | time/                   |              |
# |    fps                  | 405          |
# |    iterations           | 24           |
# |    time_elapsed         | 121          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0053757643 |
# |    clip_fraction        | 0.0321       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.551       |
# |    explained_variance   | -0.0619      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000722     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00063     |
# |    value_loss           | 0.0207       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 402          |
# |    ep_rew_mean          | 402          |
# | time/                   |              |
# |    fps                  | 409          |
# |    iterations           | 25           |
# |    time_elapsed         | 124          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0047579436 |
# |    clip_fraction        | 0.0285       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.521       |
# |    explained_variance   | -0.0239      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00516     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.0024      |
# |    value_loss           | 0.014        |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 419        |
# |    ep_rew_mean          | 419        |
# | time/                   |            |
# |    fps                  | 411        |
# |    iterations           | 26         |
# |    time_elapsed         | 129        |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.00646214 |
# |    clip_fraction        | 0.0696     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.526     |
# |    explained_variance   | -0.0345    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00412    |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.00313   |
# |    value_loss           | 0.00925    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 431          |
# |    ep_rew_mean          | 431          |
# | time/                   |              |
# |    fps                  | 413          |
# |    iterations           | 27           |
# |    time_elapsed         | 133          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0020300406 |
# |    clip_fraction        | 0.0133       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.54        |
# |    explained_variance   | -0.0143      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0129       |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -5.37e-05    |
# |    value_loss           | 0.00633      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 443          |
# |    ep_rew_mean          | 443          |
# | time/                   |              |
# |    fps                  | 417          |
# |    iterations           | 28           |
# |    time_elapsed         | 137          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0056925872 |
# |    clip_fraction        | 0.0755       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.521       |
# |    explained_variance   | 0.00813      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0301      |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00322     |
# |    value_loss           | 0.00408      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 452          |
# |    ep_rew_mean          | 452          |
# | time/                   |              |
# |    fps                  | 419          |
# |    iterations           | 29           |
# |    time_elapsed         | 141          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0057793716 |
# |    clip_fraction        | 0.0208       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.52        |
# |    explained_variance   | 0.0323       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00673     |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.000472    |
# |    value_loss           | 0.00262      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 462          |
# |    ep_rew_mean          | 462          |
# | time/                   |              |
# |    fps                  | 421          |
# |    iterations           | 30           |
# |    time_elapsed         | 145          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0020490568 |
# |    clip_fraction        | 0.0167       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.502       |
# |    explained_variance   | -0.0277      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000331    |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00132     |
# |    value_loss           | 0.0019       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 472          |
# |    ep_rew_mean          | 472          |
# | time/                   |              |
# |    fps                  | 422          |
# |    iterations           | 31           |
# |    time_elapsed         | 150          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0025162532 |
# |    clip_fraction        | 0.0287       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.511       |
# |    explained_variance   | -0.0323      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00709     |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.000891    |
# |    value_loss           | 0.00124      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 482         |
# |    ep_rew_mean          | 482         |
# | time/                   |             |
# |    fps                  | 424         |
# |    iterations           | 32          |
# |    time_elapsed         | 154         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.003624808 |
# |    clip_fraction        | 0.0319      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.481      |
# |    explained_variance   | -0.0372     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00291     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00248    |
# |    value_loss           | 0.000883    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 488          |
# |    ep_rew_mean          | 488          |
# | time/                   |              |
# |    fps                  | 424          |
# |    iterations           | 33           |
# |    time_elapsed         | 159          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0044659385 |
# |    clip_fraction        | 0.0239       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.48        |
# |    explained_variance   | -0.0505      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00281     |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.000487    |
# |    value_loss           | 0.000641     |
# ------------------------------------------

# %%
model.save("cartpole_model")

# %%
model = PPO.load("cartpole_model")

# %%
env = gym.make("CartPole-v1", render_mode="human")

obs, info = env.reset()

for _ in range(1000):

    action, _ = model.predict(obs)

    obs, reward, terminated, truncated, info = env.step(action)

    if terminated or truncated:
        obs, info = env.reset()

env.close()

# %%
env = gym.make("CartPole-v1")

episodes = 10

for episode in range(episodes):

    obs, info = env.reset()

    done = False
    total_reward = 0

    while not done:

        action, _ = model.predict(obs)

        obs, reward, terminated, truncated, info = env.step(action)

        total_reward += reward

        done = terminated or truncated

    print(f"Episode {episode+1}: Reward = {total_reward}")

env.close()
